# %% [markdown]
# # Testing
# ## Assertions

# %% [markdown]
# Assertions are the simplest type of test. They are used as a tool for bounding acceptable behavior during runtime. The assert keyword in python has the following behavior:

# %%
# when the argument is true, nothing happens
assert True == True

# %%
# when the argument is false, an assertion error is raised
assert True == False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-e5d2d9c5d319> in <module>()
#       1 # when the argument is false, an assertion error is raised
# ----> 2 assert True == False
#
# AssertionError:

# %%
# an error message can even be added to the assertion
assert True == False, "True is not False"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-5c334bceab7f> in <module>()
#       1 # an error message can even be added to the assertion
# ----> 2 assert True == False, "True is not False"
#
# AssertionError: True is not False

# %% [markdown]
# That is, assertions halt code execution instantly if the comparison is false. It does nothing at all if the comparison is true. These are therefore a very good tool for guarding the function against foolish (e.g. human) input. A simple mean function below, results in a confusing error if the input is empty.
#
# ### Assertions within code

# %%
def mean(num_list):
    return sum(num_list)/len(num_list)

mean([])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-78dbe8a12ddf> in <module>()
#       2     return sum(num_list)/len(num_list)
#       3
# ----> 4 mean([])
#
# <ipython-input-4-78dbe8a12ddf> in mean(num_list)
#       1 def mean(num_list):
# ----> 2     return sum(num_list)/len(num_list)
#       3
#       4 mean([])
#
# ZeroDivisionError: division by zero

# %% [markdown]
# If we catch the error earlier, then it is more clear that the issue is not division by zero, but will point at the line above, where it is clear that the list is empty.

# %%
def mean(num_list):
    assert len(num_list) != 0, "the input is empty but should be a list of numbers"
    return sum(num_list)/len(num_list)

mean([])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-00b3a334fbad> in <module>()
#       3     return sum(num_list)/len(num_list)
#       4
# ----> 5 mean([])
#
# <ipython-input-5-00b3a334fbad> in mean(num_list)
#       1 def mean(num_list):
# ----> 2     assert len(num_list) != 0, "the input is empty but should be a list of numbers"
#       3     return sum(num_list)/len(num_list)
#       4
#       5 mean([])
#
# AssertionError: the input is empty but should be a list of numbers

# %% [markdown]
# The advantage of assertions is their ease of use. They are rarely more than one line of code. The disadvantage is that assertions halt execution indiscriminately and the helpfulness of the resulting error message is usually quite limited.

# %%
mean("nonempty-nonlist")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b40137885f93> in <module>()
# ----> 1 mean("nonempty-nonlist")
#
# <ipython-input-5-00b3a334fbad> in mean(num_list)
#       1 def mean(num_list):
#       2     assert len(num_list) != 0, "the input is empty but should be a list of numbers"
# ----> 3     return sum(num_list)/len(num_list)
#       4
#       5 mean([])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ____
# ### Challenge: Insert an Assertion
# In the following code, use the [isinstance function](https://docs.python.org/2/library/functions.html#isinstance) to insert an assertion that checks whether the input is a list.

# %%
def mean(num_list):
    assert len(num_list) != 0, "the input is empty"
    assert isinstance(num_list, list), "the input must be a list"
    # insert your assertion here
    return sum(num_list)/len(num_list)

# %%
# Does it give the right answer?
mean([1,2,3])
# Out:
# 2.0

# %%
# Does this cause it to halt with a type message?
mean("test")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-97e4976488ed> in <module>()
#       1 # Does this cause it to halt with a type message?
# ----> 2 mean("test")
#
# <ipython-input-7-95737c8c1621> in mean(num_list)
#       1 def mean(num_list):
#       2     assert len(num_list) != 0, "the input is empty"
# ----> 3     assert isinstance(num_list, list), "the input must be a list"
#       4     # insert your assertion here
#       5     return sum(num_list)/len(num_list)
#
# AssertionError: the input must be a list

# %%
# Does this cause it to halt with an emptiness message?
mean([])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-8f75ac94dc5e> in <module>()
#       1 # Does this cause it to halt with an emptiness message?
# ----> 2 mean([])
#
# <ipython-input-7-95737c8c1621> in mean(num_list)
#       1 def mean(num_list):
# ----> 2     assert len(num_list) != 0, "the input is empty"
#       3     assert isinstance(num_list, list), "the input must be a list"
#       4     # insert your assertion here
#       5     return sum(num_list)/len(num_list)
#
# AssertionError: the input is empty

# %% [markdown]
# ----
# ### Challenge: Almost Equal
# Assertions are also helpful for catching abnormal behaviors, such as those that arise with floating point arithmetic. Using the assert keyword, how could you test whether some value is almost the same as another value?
#
# - My package, mynum, provides the number a.
# - Use the `assert` keyword to check whether the number a is greater than 2.
# - Use the `assert` keyword to check whether a is equal to 2 to within 2 decimal places.
# - Use the `assert` keyword to check that a is equal to 2 within an error of 0.003.

# %%
from mynum import a
# a is greater or equal to 2 assertion here
assert a >= 2
# a is within 0.003 of 2 assertion here
assert
# Out:
#   File "<ipython-input-11-319076a66020>", line 5
#     assert
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# To help with situations such as those above, there are classes of more helpful assertions that we will use often in later parts of this testing lesson as the building blocks of our tests. The nose testing package contains many of them.
#
# ___
#
# ### Approximate testing
#
# The NumPy numerical computing library has  `assert_allclose` for comparing numbers (or arrays of numbers) for equivalence within some tolerance:

# %%
from numpy.testing import assert_allclose
from mynum import a
assert_allclose(a, 2, atol=0.003, rtol=0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-84cb2aaf68e5> in <module>()
#       1 from numpy.testing import assert_allclose
#       2 from mynum import a
# ----> 3 assert_allclose(a, 2, atol=0.003, rtol=0)
#
# /home/bmcfee/miniconda/envs/py35/lib/python3.5/site-packages/numpy/testing/utils.py in assert_allclose(actual, desired, rtol, atol, equal_nan, err_msg, verbose)
#    1393     header = 'Not equal to tolerance rtol=%g, atol=%g' % (rtol, atol)
#    1394     assert_array_compare(compare, actual, desired, err_msg=str(err_msg),
# -> 1395                          verbose=verbose, header=header)
#    1396
#    1397 def assert_array_almost_equal_nulp(x, y, nulp=1):
#
# /home/bmcfee/miniconda/envs/py35/lib/python3.5/site-packages/numpy/testing/utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision)
#     735                                 names=('x', 'y'), precision=precision)
#     736             if not cond:
# --> 737                 raise AssertionError(msg)
#     738     except ValueError:
#     739         import traceback
#
# AssertionError:
# Not equal to tolerance rtol=0, atol=0.003
#
# (mismatch 100.0%)
#  x: array(2.005)
#  y: array(2)

# %% [markdown]
# Approximate testing is particularly useful when checking the result of numerical computations
# involving floating-point numbers, which may introduce precision errors that would confuse a strict
# equivalence test.
#
# ---
#
# An even more powerful sibling of the assertion is the exception. We’ll learn about those in the next lesson.
#
# ## Key Points
# - Assertions are one line tests embedded in code.
# - The assert keyword is used to set an assertion.
# - Assertions halt execution if the argument is false.
# - Assertions do nothing if the argument is true.
# - Assertions are the building blocks of tests.
